# %% [markdown]
# # SC1015 Mini- Project
# ---
# Lee Hanni, Ho WeiHao, Liaw Jia Xuan Celest
#
# ### Essential Libraries
#
# begin by importing the essential Python Libraries.
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
pip install yahoofinancials
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
from yahoofinancials import YahooFinancials

# %%
from yahoofinancials import YahooFinancials

stocks= ['MSFT', 'SPY','GOOG','ADBE','NKE','TSLA',"FB","DELL","HPQ","AMZN"]
#WHY WE CHOSE THEM

# %% [markdown]
# --

# %% [markdown]
# ### Machine Learning
# > use of machine learning techniques to solve specific problem
#
# > mainly chosen DecisionTree Classifier, K Nearest Nieghbour and ARIMA

# %% [markdown]
# #### Classification Decision Tree

# %%
from sklearn.tree import DecisionTreeClassifier

# Create a Decision Tree Classifier object
# you can change the max_depth as you wish

# Decision Tree with max depth = 2
tree_CA_SP_d2 = DecisionTreeClassifier(max_depth = 2)

# Decision Tree with max depth = 4
dectree = DecisionTreeClassifier(max_depth = 4)

# %%
# Import the required function from sklearn
from sklearn.model_selection import train_test_split

# Extract Response and Predictors
X = pd.DataFrame(dataframe[['RetailSales','csentiment', 'unemployment','inflationexp','federalfunds']])
y = pd.DataFrame(dataframe['change_class'])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2)
dectree.fit(X_train, y_train)

# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (192, 5) (192, 1)
# Test Set  : (48, 5) (48, 1)

# %%
# Plot the trained Decision Tree
y_train_pred = dectree.predict(X_train)

# Print the Classification Accuracy
print("Train Data")
print("Accuracy  :\t", dectree.score(X_train, y_train))
acctree=dectree.score(X_train, y_train)
print()
from sklearn.tree import plot_tree

f = plt.figure(figsize=(24,24))
plot_tree(dectree, filled=True, rounded=True, 
          feature_names=X_train.columns, 
          class_names=["down","up"])
# Out:
# Train Data
# Accuracy  :	 0.765625
# [Text(0.421875, 0.9, 'RetailSales <= 451152.5\ngini = 0.482\nsamples = 192\nvalue = [78, 114]\nclass = up'),
#  Text(0.1875, 0.7, 'inflationexp <= 2.7\ngini = 0.245\nsamples = 28\nvalue = [24, 4]\nclass = down'),
#  Text(0.125, 0.5, 'unemployment <= 9.55\ngini = 0.1\nsamples = 19\nvalue = [18, 1]\nclass = down'),
#  Text(0.0625, 0.3, 'gini = 0.0\nsamples = 9\nvalue = [9, 0]\nclass = down'),
#  Text(0.1875, 0.3, 'gini = 0.18\nsamples = 10\nvalue = [9, 1]\nclass = down'),
#  Text(0.25, 0.5, 'gini = 0.444\nsamples = 9\nvalue = [6, 3]\nclass = down'),
#  Text(0.65625, 0.7, 'unemployment <= 7.4\ngini = 0.442\nsamples = 164\nvalue = [54, 110]\nclass = up'),
#  Text(0.4375, 0.5, 'RetailSales <= 516430.5\ngini = 0.48\nsamples = 125\nvalue = [50, 75]\nclass = up'),
#  Text(0.3125, 0.3, 'inflationexp <= 2.55\ngini = 0.452\nsamples = 29\nvalue = [19, 10]\nclass = down'),
#  Text(0.25, 0.1, 'gini = 0.375\nsamples = 8\nvalue = [2, 6]\nclass = up'),
# ...
