# %% [markdown]
# # SC1015 Mini- Project
# ---
# Lee Hanni, Ho WeiHao, Liaw Jia Xuan Celest
#
# ### Essential Libraries
#
# begin by importing the essential Python Libraries.
# > NumPy : Library for Numeric Computations in Python
# > Pandas : Library for Data Acquisition and Preparation
# > Matplotlib : Low-level library for Data Visualization
# > Seaborn : Higher-level library for Data Visualization

# %%
pip install yahoofinancials
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt # we only need pyplot
sb.set() # set the default Seaborn style for graphics

# %%
from yahoofinancials import YahooFinancials

# %%
from yahoofinancials import YahooFinancials

stocks= ['MSFT', 'SPY','GOOG','ADBE','NKE','TSLA',"FB","DELL","HPQ","AMZN"]
#WHY WE CHOSE THEM

# %% [markdown]
# #### ARIMA

# %%
from statsmodels.graphics.tsaplots import plot_acf

# %%
def func(stock):
    plot_acf(stock.close)
    f=plt.figure()
    ax1=f.add_subplot(121)
    ax1.set_title('1st Order Differencing')
    ax1.plot(stock.close.diff())
    ax2=f.add_subplot(122)
    plot_acf(stock.close.diff().dropna(),ax=ax2)
    plt.show
    plot_acf(stock.close)
    f=plt.figure()
    ax1=f.add_subplot(121)
    ax1.set_title('2nd Order Differencing')
    ax1.plot(stock.close.diff().diff())
    ax2=f.add_subplot(122)
    plot_acf(stock.close.diff().diff().dropna(),ax=ax2)
    plt.show

# %%
func(dataframe)

# %%
#AIC measures the goodness of fit

# %%
series = df_spy['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=87.351
# ARIMA(0, 0, 1) RMSE=52.658
# ARIMA(0, 0, 2) RMSE=40.462
# ARIMA(0, 1, 0) RMSE=17.569
# ARIMA(0, 1, 1) RMSE=17.451
# ARIMA(0, 1, 2) RMSE=20.140
# ARIMA(0, 2, 0) RMSE=29.892
# ARIMA(0, 2, 1) RMSE=18.076
# ARIMA(0, 2, 2) RMSE=17.176
# ARIMA(1, 0, 0) RMSE=18.881
# ARIMA(1, 0, 1) RMSE=23.409
# ARIMA(1, 0, 2) RMSE=22.497
# ARIMA(1, 1, 0) RMSE=17.262
# ARIMA(1, 1, 1) RMSE=19.205
# ARIMA(1, 1, 2) RMSE=17.009
# ARIMA(1, 2, 0) RMSE=20.961
# ARIMA(1, 2, 1) RMSE=14.668
# ARIMA(1, 2, 2) RMSE=19.505
# ARIMA(2, 0, 0) RMSE=19.435
# ARIMA(2, 0, 1) RMSE=22.552
# ARIMA(2, 0, 2) RMSE=23.044
# ARIMA(2, 1, 0) RMSE=18.751
# ARIMA(2, 1, 1) RMSE=21.643
# ARIMA(2, 1, 2) RMSE=19.275
# ARIMA(2, 2, 0) RMSE=25.783
# ARIMA(2, 2, 1) RMSE=17.729
# ARIMA(2, 2, 2) RMSE=19.552
# ARIMA(4, 0, 0) RMSE=24.311
# ARIMA(4, 0, 1) RMSE=19.649
# ARIMA(4, 0, 2) RMSE=19.449
# ARIMA(4, 1, 0) RMSE=14.556
# ARIMA(4, 1, 1) RMSE=17.382
# ARIMA(4, 1, 2) RMSE=14.663
# ARIMA(4, 2, 0) RMSE=15.188
# ...

# %%
series = df_facebook['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=73.511
# ARIMA(0, 0, 1) RMSE=46.194
# ARIMA(0, 0, 2) RMSE=31.591
# ARIMA(0, 1, 0) RMSE=19.734
# ARIMA(0, 1, 1) RMSE=20.953
# ARIMA(0, 1, 2) RMSE=21.768
# ARIMA(0, 2, 0) RMSE=28.795
# ARIMA(0, 2, 1) RMSE=21.980
# ARIMA(0, 2, 2) RMSE=23.130
# ARIMA(1, 0, 0) RMSE=20.751
# ARIMA(1, 0, 1) RMSE=23.514
# ARIMA(1, 0, 2) RMSE=23.136
# ARIMA(1, 1, 0) RMSE=20.246
# ARIMA(1, 1, 1) RMSE=21.081
# ARIMA(1, 1, 2) RMSE=21.819
# ARIMA(1, 2, 0) RMSE=26.592
# ARIMA(1, 2, 1) RMSE=22.679
# ARIMA(1, 2, 2) RMSE=23.966
# ARIMA(2, 0, 0) RMSE=21.962
# ARIMA(2, 0, 1) RMSE=23.294
# ARIMA(2, 0, 2) RMSE=24.046
# ARIMA(2, 1, 0) RMSE=21.710
# ARIMA(2, 1, 1) RMSE=22.057
# ARIMA(2, 1, 2) RMSE=22.531
# ARIMA(2, 2, 0) RMSE=26.620
# ARIMA(2, 2, 1) RMSE=27.272
# ARIMA(2, 2, 2) RMSE=24.602
# ARIMA(4, 0, 0) RMSE=25.067
# ARIMA(4, 0, 1) RMSE=24.608
# ARIMA(4, 0, 2) RMSE=25.154
# ARIMA(4, 1, 0) RMSE=22.504
# ARIMA(4, 1, 1) RMSE=19.650
# ARIMA(4, 1, 2) RMSE=22.741
# ARIMA(4, 2, 0) RMSE=23.866
# ...

# %%
series = df_microsoft['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=80.098
# ARIMA(0, 0, 1) RMSE=52.594
# ARIMA(0, 0, 2) RMSE=39.980
# ARIMA(0, 1, 0) RMSE=22.324
# ARIMA(0, 1, 1) RMSE=22.600
# ARIMA(0, 1, 2) RMSE=23.853
# ARIMA(0, 2, 0) RMSE=34.612
# ARIMA(0, 2, 1) RMSE=21.901
# ARIMA(0, 2, 2) RMSE=20.660
# ARIMA(1, 0, 0) RMSE=23.073
# ARIMA(1, 0, 1) RMSE=23.641
# ARIMA(1, 0, 2) RMSE=25.637
# ARIMA(1, 1, 0) RMSE=22.941
# ARIMA(1, 1, 1) RMSE=20.675
# ARIMA(1, 1, 2) RMSE=23.814
# ARIMA(1, 2, 0) RMSE=24.701
# ARIMA(1, 2, 1) RMSE=20.842
# ARIMA(1, 2, 2) RMSE=21.596
# ARIMA(2, 0, 0) RMSE=24.216
# ARIMA(2, 0, 1) RMSE=21.283
# ARIMA(2, 0, 2) RMSE=24.031
# ARIMA(2, 1, 0) RMSE=22.547
# ARIMA(2, 1, 1) RMSE=23.467
# ARIMA(2, 1, 2) RMSE=21.749
# ARIMA(2, 2, 0) RMSE=26.584
# ARIMA(2, 2, 1) RMSE=21.210
# ARIMA(2, 2, 2) RMSE=19.788
# ARIMA(4, 0, 0) RMSE=25.552
# ARIMA(4, 0, 1) RMSE=24.674
# LU decomposition error.
# ARIMA(4, 1, 0) RMSE=20.936
# ARIMA(4, 1, 1) RMSE=21.668
# ARIMA(4, 1, 2) RMSE=20.607
# ARIMA(4, 2, 0) RMSE=20.951
# ...

# %%
series = df_dell['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=16.868
# ARIMA(0, 0, 1) RMSE=8.835
# ARIMA(0, 0, 2) RMSE=7.276
# ARIMA(0, 1, 0) RMSE=1.637
# ARIMA(0, 1, 1) RMSE=1.606
# ARIMA(0, 1, 2) RMSE=1.602
# ARIMA(0, 2, 0) RMSE=2.335
# ARIMA(0, 2, 1) RMSE=1.824
# ARIMA(0, 2, 2) RMSE=1.823
# ARIMA(1, 0, 0) RMSE=1.797
# ARIMA(1, 0, 1) RMSE=1.759
# ARIMA(1, 0, 2) RMSE=1.745
# ARIMA(1, 1, 0) RMSE=1.615
# ARIMA(1, 1, 1) RMSE=1.738
# ARIMA(1, 1, 2) RMSE=1.724
# ARIMA(1, 2, 0) RMSE=2.384
# ARIMA(1, 2, 1) RMSE=1.828
# ARIMA(1, 2, 2) RMSE=1.850
# ARIMA(2, 0, 0) RMSE=1.763
# ARIMA(2, 0, 1) RMSE=1.925
# ARIMA(2, 0, 2) RMSE=2.065
# ARIMA(2, 1, 0) RMSE=1.714
# ARIMA(2, 1, 1) RMSE=1.736
# ARIMA(2, 1, 2) RMSE=1.769
# ARIMA(2, 2, 0) RMSE=2.677
# ARIMA(2, 2, 1) RMSE=2.319
# ARIMA(2, 2, 2) RMSE=1.994
# ARIMA(4, 0, 0) RMSE=2.316
# ARIMA(4, 0, 1) RMSE=2.402
# ARIMA(4, 0, 2) RMSE=2.180
# ARIMA(4, 1, 0) RMSE=2.298
# ARIMA(4, 1, 1) RMSE=2.409
# ARIMA(4, 1, 2) RMSE=2.576
# ARIMA(4, 2, 0) RMSE=2.736
# ARIMA(4, 2, 1) RMSE=2.000
# ...

# %%
series = df_hp['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=8.874
# ARIMA(0, 0, 1) RMSE=5.867
# ARIMA(0, 0, 2) RMSE=3.815
# ARIMA(0, 1, 0) RMSE=2.844
# ARIMA(0, 1, 1) RMSE=3.080
# ARIMA(0, 1, 2) RMSE=3.080
# ARIMA(0, 2, 0) RMSE=4.180
# ARIMA(0, 2, 1) RMSE=3.442
# ARIMA(0, 2, 2) RMSE=3.504
# ARIMA(1, 0, 0) RMSE=2.950
# ARIMA(1, 0, 1) RMSE=3.229
# ARIMA(1, 0, 2) RMSE=3.225
# ARIMA(1, 1, 0) RMSE=3.112
# ARIMA(1, 1, 1) RMSE=3.356
# ARIMA(1, 1, 2) RMSE=3.213
# ARIMA(1, 2, 0) RMSE=3.877
# ARIMA(1, 2, 1) RMSE=3.492
# ARIMA(1, 2, 2) RMSE=3.549
# ARIMA(2, 0, 0) RMSE=3.372
# ARIMA(2, 0, 1) RMSE=3.526
# ARIMA(2, 0, 2) RMSE=3.650
# ARIMA(2, 1, 0) RMSE=3.228
# ARIMA(2, 1, 1) RMSE=3.340
# ARIMA(2, 1, 2) RMSE=3.317
# ARIMA(2, 2, 0) RMSE=4.043
# ARIMA(2, 2, 1) RMSE=3.899
# ARIMA(2, 2, 2) RMSE=4.091
# ARIMA(4, 0, 0) RMSE=3.873
# ARIMA(4, 0, 1) RMSE=3.583
# ARIMA(4, 0, 2) RMSE=4.063
# ARIMA(4, 1, 0) RMSE=3.522
# ARIMA(4, 1, 1) RMSE=3.569
# ARIMA(4, 1, 2) RMSE=3.418
# ARIMA(4, 2, 0) RMSE=3.827
# ARIMA(4, 2, 1) RMSE=3.904
# ...

# %%
series = df_tesla['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=398.688
# ARIMA(0, 0, 1) RMSE=241.370
# ARIMA(0, 0, 2) RMSE=197.284
# ARIMA(0, 1, 0) RMSE=129.850
# ARIMA(0, 1, 1) RMSE=128.585
# ARIMA(0, 1, 2) RMSE=131.786
# ARIMA(0, 2, 0) RMSE=162.657
# ARIMA(0, 2, 1) RMSE=131.313
# ARIMA(0, 2, 2) RMSE=131.798
# ARIMA(1, 0, 0) RMSE=133.522
# ARIMA(1, 0, 1) RMSE=131.776
# ARIMA(1, 0, 2) RMSE=133.388
# ARIMA(1, 1, 0) RMSE=128.700
# ARIMA(1, 1, 1) RMSE=136.826
# ARIMA(1, 1, 2) RMSE=129.234
# ARIMA(1, 2, 0) RMSE=161.429
# ARIMA(1, 2, 1) RMSE=131.467
# ARIMA(1, 2, 2) RMSE=140.893
# ARIMA(2, 0, 0) RMSE=130.968
# ARIMA(2, 0, 1) RMSE=139.735
# ARIMA(2, 0, 2) RMSE=141.020
# ARIMA(2, 1, 0) RMSE=130.256
# ARIMA(2, 1, 1) RMSE=139.917
# ARIMA(2, 1, 2) RMSE=132.353
# ARIMA(2, 2, 0) RMSE=166.376
# ARIMA(2, 2, 1) RMSE=132.808
# ARIMA(2, 2, 2) RMSE=150.247
# ARIMA(4, 0, 0) RMSE=136.810
# ARIMA(4, 0, 1) RMSE=140.739
# ARIMA(4, 0, 2) RMSE=129.273
# ARIMA(4, 1, 0) RMSE=137.324
# ARIMA(4, 1, 1) RMSE=145.968
# ARIMA(4, 1, 2) RMSE=157.489
# ...

# %%
series = df_adobe['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=138.604
# ARIMA(0, 0, 1) RMSE=96.307
# ARIMA(0, 0, 2) RMSE=87.775
# ARIMA(0, 1, 0) RMSE=62.344
# ARIMA(0, 1, 1) RMSE=64.679
# ARIMA(0, 1, 2) RMSE=73.249
# ARIMA(0, 2, 0) RMSE=92.417
# ARIMA(0, 2, 1) RMSE=64.309
# ARIMA(0, 2, 2) RMSE=66.841
# ARIMA(1, 0, 0) RMSE=64.073
# ARIMA(1, 0, 1) RMSE=68.478
# ARIMA(1, 0, 2) RMSE=71.819
# ARIMA(1, 1, 0) RMSE=64.917
# ARIMA(1, 1, 1) RMSE=66.671
# ARIMA(1, 1, 2) RMSE=72.158
# ARIMA(1, 2, 0) RMSE=81.421
# ARIMA(1, 2, 1) RMSE=66.544
# ARIMA(1, 2, 2) RMSE=68.970
# ARIMA(2, 0, 0) RMSE=70.122
# ARIMA(2, 0, 1) RMSE=74.307
# ARIMA(2, 0, 2) RMSE=70.810
# ARIMA(2, 1, 0) RMSE=67.295
# ARIMA(2, 1, 1) RMSE=68.438
# ARIMA(2, 1, 2) RMSE=71.951
# ARIMA(2, 2, 0) RMSE=75.203
# ARIMA(2, 2, 1) RMSE=67.412
# ARIMA(2, 2, 2) RMSE=77.672
# ARIMA(4, 0, 0) RMSE=74.788
# ARIMA(4, 0, 1) RMSE=76.485
# ARIMA(4, 0, 2) RMSE=75.784
# ARIMA(4, 1, 0) RMSE=67.448
# ARIMA(4, 1, 1) RMSE=66.836
# ARIMA(4, 1, 2) RMSE=73.195
# ARIMA(4, 2, 0) RMSE=64.427
# ...

# %%
series = df_nike['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=36.796
# ARIMA(0, 0, 1) RMSE=23.275
# ARIMA(0, 0, 2) RMSE=19.445
# ARIMA(0, 1, 0) RMSE=13.907
# ARIMA(0, 1, 1) RMSE=15.056
# ARIMA(0, 1, 2) RMSE=15.024
# ARIMA(0, 2, 0) RMSE=18.805
# ARIMA(0, 2, 1) RMSE=14.210
# ARIMA(0, 2, 2) RMSE=16.546
# ARIMA(1, 0, 0) RMSE=14.229
# ARIMA(1, 0, 1) RMSE=15.323
# ARIMA(1, 0, 2) RMSE=15.467
# ARIMA(1, 1, 0) RMSE=14.659
# ARIMA(1, 1, 1) RMSE=15.288
# ARIMA(1, 1, 2) RMSE=15.200
# ARIMA(1, 2, 0) RMSE=18.498
# ARIMA(1, 2, 1) RMSE=15.306
# ARIMA(1, 2, 2) RMSE=16.201
# ARIMA(2, 0, 0) RMSE=15.756
# ARIMA(2, 0, 1) RMSE=15.562
# ARIMA(2, 0, 2) RMSE=15.944
# ARIMA(2, 1, 0) RMSE=14.439
# ARIMA(2, 1, 1) RMSE=15.056
# ARIMA(2, 1, 2) RMSE=15.908
# ARIMA(2, 2, 0) RMSE=19.219
# ARIMA(2, 2, 1) RMSE=16.711
# ARIMA(2, 2, 2) RMSE=16.536
# ARIMA(4, 0, 0) RMSE=17.480
# ARIMA(4, 0, 1) RMSE=18.463
# ARIMA(4, 0, 2) RMSE=18.476
# ARIMA(4, 1, 0) RMSE=16.487
# ARIMA(4, 1, 1) RMSE=16.468
# ARIMA(4, 1, 2) RMSE=19.068
# ARIMA(4, 2, 0) RMSE=17.978
# ...

# %%
series = df_amazon['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=374.082
# ARIMA(0, 0, 1) RMSE=325.629
# ARIMA(0, 0, 2) RMSE=266.087
# ARIMA(0, 1, 0) RMSE=196.547
# ARIMA(0, 1, 1) RMSE=216.101
# ARIMA(0, 1, 2) RMSE=176.740
# ARIMA(0, 2, 0) RMSE=345.934
# ARIMA(0, 2, 1) RMSE=224.095
# ARIMA(0, 2, 2) RMSE=233.550
# ARIMA(1, 0, 0) RMSE=189.341
# ARIMA(1, 0, 1) RMSE=221.751
# ARIMA(1, 0, 2) RMSE=295.870
# ARIMA(1, 1, 0) RMSE=216.629
# ARIMA(1, 1, 1) RMSE=221.288
# ARIMA(1, 1, 2) RMSE=236.679
# ARIMA(1, 2, 0) RMSE=242.032
# ARIMA(1, 2, 1) RMSE=228.120
# ARIMA(1, 2, 2) RMSE=264.450
# ARIMA(2, 0, 0) RMSE=216.498
# ARIMA(2, 0, 1) RMSE=193.532
# ARIMA(2, 0, 2) RMSE=282.849
# ARIMA(2, 1, 0) RMSE=216.693
# ARIMA(2, 1, 1) RMSE=241.473
# ARIMA(2, 1, 2) RMSE=240.042
# ARIMA(2, 2, 0) RMSE=250.161
# ARIMA(2, 2, 1) RMSE=241.089
# ARIMA(2, 2, 2) RMSE=249.115
# ARIMA(4, 0, 0) RMSE=241.419
# ARIMA(4, 0, 1) RMSE=204.728
# ARIMA(4, 0, 2) RMSE=254.689
# ARIMA(4, 1, 0) RMSE=204.456
# ARIMA(4, 1, 1) RMSE=213.128
# ARIMA(4, 1, 2) RMSE=306.063
# ...

# %%
series = df_google['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=898.689
# ARIMA(0, 0, 1) RMSE=560.053
# ARIMA(0, 0, 2) RMSE=404.713
# ARIMA(0, 1, 0) RMSE=178.739
# ARIMA(0, 1, 1) RMSE=178.766
# ARIMA(0, 1, 2) RMSE=160.567
# ARIMA(0, 2, 0) RMSE=313.051
# ARIMA(0, 2, 1) RMSE=191.140
# ARIMA(0, 2, 2) RMSE=155.261
# ARIMA(1, 0, 0) RMSE=186.116
# ARIMA(1, 0, 1) RMSE=190.917
# ARIMA(1, 0, 2) RMSE=167.624
# ARIMA(1, 1, 0) RMSE=178.507
# ARIMA(1, 1, 1) RMSE=188.977
# ARIMA(1, 1, 2) RMSE=125.414
# ARIMA(1, 2, 0) RMSE=204.777
# ARIMA(1, 2, 1) RMSE=172.635
# ARIMA(1, 2, 2) RMSE=152.361
# ARIMA(2, 0, 0) RMSE=190.677
# ARIMA(2, 0, 1) RMSE=156.892
# ARIMA(2, 0, 2) RMSE=187.406
# ARIMA(2, 1, 0) RMSE=172.348
# ARIMA(2, 1, 1) RMSE=162.215
# ARIMA(2, 1, 2) RMSE=120.033
# ARIMA(2, 2, 0) RMSE=191.505
# ARIMA(2, 2, 1) RMSE=177.579
# ARIMA(2, 2, 2) RMSE=159.308
# ARIMA(4, 0, 0) RMSE=178.245
# ARIMA(4, 0, 1) RMSE=147.553
# ARIMA(4, 0, 2) RMSE=152.029
# ARIMA(4, 1, 0) RMSE=139.218
# ARIMA(4, 1, 1) RMSE=130.396
# ARIMA(4, 1, 2) RMSE=154.366
# ...

# %%
# grid search ARIMA parameters for time series
import warnings
from math import sqrt
from pandas import read_csv
from pandas import datetime
from statsmodels.tsa.arima.model import ARIMA
from sklearn.metrics import mean_squared_error

# evaluate an ARIMA model for a given order (p,d,q)
def evaluate_arima_model(X, arima_order):
	# prepare training dataset
	train_size = int(len(X) * 0.66)
	train, test = X[0:train_size], X[train_size:]
	history = [x for x in train]
	# make predictions
	predictions = list()
	for t in range(len(test)):
		model = ARIMA(history, order=arima_order)
		model_fit = model.fit()
		yhat = model_fit.forecast()[0]
		predictions.append(yhat)
		history.append(test[t])
	# calculate out of sample error
	rmse = sqrt(mean_squared_error(test, predictions))
	return rmse

# evaluate combinations of p, d and q values for an ARIMA model
def evaluate_models(dataset, p_values, d_values, q_values):
	dataset = dataset.astype('float32')
	best_score, best_cfg = float("inf"), None
	for p in p_values:
		for d in d_values:
			for q in q_values:
				order = (p,d,q)
				try:
					rmse = evaluate_arima_model(dataset, order)
					if rmse < best_score:
						best_score, best_cfg = rmse, order
					print('ARIMA%s RMSE=%.3f' % (order,rmse))
				except Exception as e:
					print(e)
					continue
	print('Best ARIMA%s RMSE=%.3f' % (best_cfg, best_score))

# load dataset
def parser(x):
	return datetime.strptime('190'+x, '%Y-%m')
series = df_google['close']
# evaluate parameters
p_values = [0, 1, 2, 4, 6, 8, 10]
d_values = range(0, 3)
q_values = range(0, 3)
warnings.filterwarnings("ignore")
evaluate_models(series.values, p_values, d_values, q_values)
# Out:
# ARIMA(0, 0, 0) RMSE=898.689
# ARIMA(0, 0, 1) RMSE=560.053
# ARIMA(0, 0, 2) RMSE=404.713
# ARIMA(0, 1, 0) RMSE=178.739
# ARIMA(0, 1, 1) RMSE=178.766
# ARIMA(0, 1, 2) RMSE=160.567
# ARIMA(0, 2, 0) RMSE=313.051
# ARIMA(0, 2, 1) RMSE=191.140
# ARIMA(0, 2, 2) RMSE=155.261
# ARIMA(1, 0, 0) RMSE=186.116
# ARIMA(1, 0, 1) RMSE=190.917
# ARIMA(1, 0, 2) RMSE=167.624
# ARIMA(1, 1, 0) RMSE=178.507
# ARIMA(1, 1, 1) RMSE=188.977
# ARIMA(1, 1, 2) RMSE=125.414
# ARIMA(1, 2, 0) RMSE=204.777
# ARIMA(1, 2, 1) RMSE=172.635
# ARIMA(1, 2, 2) RMSE=152.361
# ARIMA(2, 0, 0) RMSE=190.677
# ARIMA(2, 0, 1) RMSE=156.892
# ARIMA(2, 0, 2) RMSE=187.406
# ARIMA(2, 1, 0) RMSE=172.348
# ARIMA(2, 1, 1) RMSE=162.215
# ARIMA(2, 1, 2) RMSE=120.033
# ARIMA(2, 2, 0) RMSE=191.505
# ARIMA(2, 2, 1) RMSE=177.579
# ARIMA(2, 2, 2) RMSE=159.308
# ARIMA(4, 0, 0) RMSE=178.245
# ARIMA(4, 0, 1) RMSE=147.553
# ARIMA(4, 0, 2) RMSE=152.029
# ARIMA(4, 1, 0) RMSE=139.218
# ARIMA(4, 1, 1) RMSE=130.396
# ARIMA(4, 1, 2) RMSE=154.366
# ...

# %%
def func(abc, a , b, c):
    from statsmodels.tsa.arima_model import ARIMA
    arima_model=ARIMA(abc.close, order=(a,b,c))
    model=arima_model.fit()
    print(model.summary())
    model.plot_predict(dynamic=False)
    plt.show()
    y_pred=pd.Series(model.forecast(12)[0],index=abc.close[12:].index)
    y_true=abc.close[12:]
    mape = np.mean(np.abs(y_pred-y_true)/np.abs(y_true))
    print("MAPE: "+str(mape))
    
func(df_spy,4,1,0)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                 -93.354
# Method:                       css-mle   S.D. of innovations             13.498
# Date:                Sat, 23 Apr 2022   AIC                            198.708
# Time:                        01:27:45   BIC                            205.521
# Sample:                             1   HQIC                           200.421
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             8.4385      1.190      7.092      0.000       6.107      10.771
# ar.L1.D.close    -0.8220      0.233     -3.526      0.000      -1.279      -0.365
# ar.L2.D.close    -0.5622      0.279     -2.018      0.044      -1.108      -0.016
# ...

# %%
func(df_microsoft,2,2,2)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:               D2.close   No. Observations:                   22
# Model:                 ARIMA(2, 2, 2)   Log Likelihood                 -93.132
# Method:                       css-mle   S.D. of innovations             15.426
# Date:                Sat, 23 Apr 2022   AIC                            198.264
# Time:                        01:27:45   BIC                            204.810
# Sample:                             2   HQIC                           199.806
#
# ...
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const             -0.4054      0.453     -0.896      0.370      -1.292       0.482
# ar.L1.D2.close    -1.1583      0.126     -9.166      0.000      -1.406      -0.911
# ar.L2.D2.close    -0.1583        nan        nan        nan         nan         nan
# ...

# %%
func(df_facebook,4,1,0)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(4, 1, 0)   Log Likelihood                -102.823
# Method:                       css-mle   S.D. of innovations             20.998
# Date:                Sat, 23 Apr 2022   AIC                            217.647
# Time:                        01:27:45   BIC                            224.460
# Sample:                             1   HQIC                           219.360
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             5.0327      4.938      1.019      0.308      -4.645      14.711
# ar.L1.D.close     0.0256      0.221      0.116      0.908      -0.408       0.459
# ar.L2.D.close    -0.2091      0.218     -0.957      0.339      -0.637       0.219
# ...

# %%
func(df_google, 6,0,0)
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                   24
# Model:                     ARMA(6, 0)   Log Likelihood                -147.049
# Method:                       css-mle   S.D. of innovations             93.939
# Date:                Sat, 23 Apr 2022   AIC                            310.098
# Time:                        01:27:46   BIC                            319.522
# Sample:                             0   HQIC                           312.598
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const        1946.4530    218.053      8.927      0.000    1519.077    2373.829
# ar.L1.close     0.4453      0.206      2.160      0.031       0.041       0.849
# ar.L2.close     0.7439      0.152      4.891      0.000       0.446       1.042
# ...

# %%
func(df_adobe,1,0,0)
# Out:
#                               ARMA Model Results
# ...
# Dep. Variable:                  close   No. Observations:                   24
# Model:                     ARMA(1, 0)   Log Likelihood                -126.831
# Method:                       css-mle   S.D. of innovations             46.249
# Date:                Sat, 23 Apr 2022   AIC                            259.663
# Time:                        01:27:46   BIC                            263.197
# Sample:                             0   HQIC                           260.600
#
# ...
#                   coef    std err          z      P>|z|      [0.025      0.975]
# -------------------------------------------------------------------------------
# const         476.2937     64.711      7.360      0.000     349.462     603.125
# ar.L1.close     0.8838      0.088     10.053      0.000       0.711       1.056
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
func(df_nike,0,1,0)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 -86.700
# Method:                           css   S.D. of innovations             10.492
# Date:                Sat, 23 Apr 2022   AIC                            177.400
# Time:                        01:27:46   BIC                            179.671
# Sample:                             1   HQIC                           177.971
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          2.5517      2.188      1.166      0.243      -1.736       6.840
# ...
# MAPE: 0.0957499732351797

# %%
func(df_tesla,0,1,1)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(0, 1, 1)   Log Likelihood                -139.886
# Method:                       css-mle   S.D. of innovations            105.919
# Date:                Sat, 23 Apr 2022   AIC                            285.773
# Time:                        01:27:46   BIC                            289.179
# Sample:                             1   HQIC                           286.630
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            33.7162     25.051      1.346      0.178     -15.383      82.816
# ma.L1.D.close     0.1360      0.259      0.526      0.599      -0.371       0.643
#                                     Roots
# ...
#                   Real          Imaginary           Modulus         Frequency
# ...

# %%
func(df_dell,0,1,2)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                 -47.390
# Method:                       css-mle   S.D. of innovations              1.786
# Date:                Sat, 23 Apr 2022   AIC                            102.780
# Time:                        01:27:46   BIC                            107.322
# Sample:                             1   HQIC                           103.922
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             1.6996      0.085     20.000      0.000       1.533       1.866
# ma.L1.D.close    -0.3043      0.228     -1.333      0.183      -0.752       0.143
# ma.L2.D.close    -0.6957      0.200     -3.479      0.001      -1.088      -0.304
# ...

# %%
func(df_hp,0,1,0)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(0, 1, 0)   Log Likelihood                 -53.830
# Method:                           css   S.D. of innovations              2.513
# Date:                Sat, 23 Apr 2022   AIC                            111.660
# Time:                        01:27:47   BIC                            113.931
# Sample:                             1   HQIC                           112.231
#
# ...
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.6930      0.524      1.323      0.186      -0.334       1.720
# ...
# MAPE: 0.31087534024777214

# %%
func(df_amazon,0,1,2)
# Out:
#                              ARIMA Model Results
# ...
# Dep. Variable:                D.close   No. Observations:                   23
# Model:                 ARIMA(0, 1, 2)   Log Likelihood                -157.583
# Method:                       css-mle   S.D. of innovations            228.706
# Date:                Sat, 23 Apr 2022   AIC                            323.165
# Time:                        01:27:47   BIC                            327.707
# Sample:                             1   HQIC                           324.308
#
# ...
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const            48.8793     45.774      1.068      0.286     -40.837     138.595
# ma.L1.D.close    -0.0459      0.221     -0.208      0.835      -0.479       0.387
# ma.L2.D.close     0.0010      0.181      0.005      0.996      -0.354       0.356
# ...

# %%
avg=(0.04442657979084793+0.31087534024777214+0.38986211513159014+0.4297899264042507+0.0957499732351797+0.14149282403920174+0.2572918059341692+0.0792991372303431+0.16647744535627337+0.21193394583043623)/10
print("avg=",avg)
# Out:
# avg= 0.21271990932000642

# %%
print("Accuracy of ARIMA model =",round(1-avg,3))
print("Accuracy of K-Nearest-Neighbour = ", round((accuracy_score(y_pred,y_test)),3))
print("Accuracy of Decision Tree Classifier =",round(acctree,3))  # from cell __
# Out:
# Accuracy of ARIMA model = 0.787
# Accuracy of K-Nearest-Neighbour =  0.771
# Accuracy of Decision Tree Classifier = 0.766

# %% [markdown]
# # Best Prediction Model is ARIMA

# %%
new_df=[]

    
for item in stocks:
    yahoo_financials = YahooFinancials(item)
    data = yahoo_financials.get_historical_price_data("2022-01-01", "2022-04-02", "monthly")
    new_df.append(pd.DataFrame(data[item]['prices']))
    new_df[-1]['name'] = item
    
    for key in data[item]['prices']:
        #print(key)
        continue
## delete the first coloumn , clean data
display(new_df[9])
# Out:
#          date         high          low         open        close    volume  \
# 0  1641013200  3428.000000  2707.040039  3351.000000  2991.469971  76232700
# 1  1643691600  3276.689941  2766.659912  3000.000000  3071.260010  84480200
# 2  1646110800  3416.629883  2671.449951  3054.649902  3259.949951  81424300
# 3  1648785600  3367.889893  2951.790039  3282.989990  2965.919922  39542900
#
#       adjclose formatted_date  name
# 0  2991.469971     2022-01-01  AMZN
# 1  3071.260010     2022-02-01  AMZN
# 2  3259.949951     2022-03-01  AMZN
# 3  2965.919922     2022-04-01  AMZN

# %%
def forecast(old_df, new_df,a,b,c):
    plt.figure(figsize=(30,15))
    plt.plot(old_df['formatted_date'],old_df['close'],color='blue')
    from statsmodels.tsa.arima_model import ARIMA
    arima_model=ARIMA(old_df.close, order=(a,b,c))
    model=arima_model.fit()
    #model.plot_predict(dynamic=False)
    y_pred=pd.Series(model.forecast(4)[0],index=new_df.close[0:].index)
    y_true=new_df.close[0:]
    print("Prediction:")
    print(y_pred)
    print("Actual:")
    print(y_true)
    
    plt.plot(new_df['formatted_date'],y_pred)
    plt.plot(new_df['formatted_date'],y_true,color='blue')
    plt.show()

# %%
forecast(df_microsoft,new_df[0],2,2,2)
# Out:
# Prediction:
# 0    318.417950
# 1    320.243366
# 2    322.441237
# 3    324.157098
# dtype: float64
# Actual:
# 0    310.980011
# 1    298.790009
# 2    308.309998
# 3    280.809998
# Name: close, dtype: float64

# %%
forecast(df_amazon,new_df[9],0,1,2)
# Out:
# Prediction:
# 0    3058.588031
# 1    3107.083128
# 2    3155.962401
# 3    3204.841674
# dtype: float64
# Actual:
# 0    2991.469971
# 1    3071.260010
# 2    3259.949951
# 3    2965.919922
# Name: close, dtype: float64

# %%
forecast(df_spy,new_df[1],4,1,0)
# Out:
# Prediction:
# 0    488.107604
# 1    484.874280
# 2    499.203257
# 3    492.852684
# dtype: float64
# Actual:
# 0    449.910004
# 1    436.630005
# 2    451.640015
# 3    438.059998
# Name: close, dtype: float64

# %%
forecast(df_facebook,new_df[6],4,1,0)
# Out:
# Prediction:
# 0    311.784992
# 1    322.702760
# 2    326.695231
# 3    324.473294
# dtype: float64
# Actual:
# 0    313.260010
# 1    211.029999
# 2    222.360001
# 3    188.070007
# Name: close, dtype: float64

# %%
forecast(df_google,new_df[2],6,0,0)
# Out:
# Prediction:
# 0    2883.002225
# 1    2576.194642
# 2    2628.388105
# 3    2456.464470
# dtype: float64
# Actual:
# 0    2713.969971
# 1    2697.820068
# 2    2792.989990
# 3    2498.750000
# Name: close, dtype: float64

# %%
forecast(df_adobe,new_df[3],1,0,0)
# Out:
# Prediction:
# 0    527.559367
# 1    521.602040
# 2    516.336983
# 3    511.683753
# dtype: float64
# Actual:
# 0    534.299988
# 1    467.679993
# 2    455.619995
# 3    417.480011
# Name: close, dtype: float64

# %%
forecast(df_nike,new_df[4],0,1,0)
# Out:
# Prediction:
# 0    150.621747
# 1    153.173486
# 2    155.725226
# 3    158.276966
# dtype: float64
# Actual:
# 0    148.070007
# 1    136.550003
# 2    134.559998
# 3    135.460007
# Name: close, dtype: float64

# %%
forecast(df_tesla,new_df[5],0,1,1)
# Out:
# Prediction:
# 0     951.664662
# 1     985.380813
# 2    1019.096964
# 3    1052.813116
# dtype: float64
# Actual:
# 0     936.719971
# 1     870.429993
# 2    1077.599976
# 3    1008.780029
# Name: close, dtype: float64

# %%
forecast(df_dell,new_df[7],0,1,2)
# Out:
# Prediction:
# 0    60.220702
# 1    63.307603
# 2    65.007218
# 3    66.706832
# dtype: float64
# Actual:
# 0    56.810001
# 1    50.959999
# 2    50.189999
# 3    48.209999
# Name: close, dtype: float64

# %%
forecast(df_hp,new_df[8],0,1,0)
# Out:
# Prediction:
# 0    37.423043
# 1    38.116086
# 2    38.809130
# 3    39.502173
# dtype: float64
# Actual:
# 0    36.730000
# 1    34.360001
# 2    36.299999
# 3    38.290001
# Name: close, dtype: float64

# %% [markdown]
# # END
